# %%
import pandas as pd
import numpy as np

data = pd.read_csv("data.csv")
print(data.head())

gap = (data["TF_Recalc(10)"] - data["One_Fare_Static_Sim"]) / data["One_Fare_Static_Sim"]
optcomp = (data["DP_Sim"] - data["TF_Recalc(10)"]) / data["DP_Sim"]
print(optcomp)
# Out:
#    TF_Recalc(10)  TF_Recalc(5)  TF_Recalc(2)  TF_Recalc(1)  DP_Calc   DP_Sim  \
# 0        118.489       117.867       113.803       115.015  122.280  121.218
# 1        109.171       108.429       105.587       106.145  113.486  114.385
# 2        112.747       110.768       109.110       109.595  117.149  118.243
# 3        113.196       113.282       110.350       109.757  117.628  116.477
# 4        108.289       108.185       105.672       104.584  113.896  111.330
#
#    One_Fare_Static_Sim        Seed
# 0              112.775  4252231342
# 1              103.860   292042488
# 2              106.145  3095271442
# 3              108.017  1704227915
# 4              104.802  3448266953
# 0     0.022513
# 1     0.045583
# 2     0.046481
# 3     0.028169
# 4     0.027315
# 5     0.016614
# 6     0.042065
# 7     0.032939
# 8     0.042978
# 9     0.050001
# 10    0.044655
# 11    0.046928
# 12    0.051061
# 13    0.044464
# 14    0.053506
# 15    0.054820
# 16    0.046420
# ...
